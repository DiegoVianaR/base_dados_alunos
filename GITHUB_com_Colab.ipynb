# %% [markdown]
# <a href="https://colab.research.google.com/github/DiegoVianaR/base_dados_alunos/blob/main/GITHUB_com_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!git clone COLAR A URL

# !git clone https://github.com/DiegoVianaR/base_dados_alunos
# Out:
# Cloning into 'base_dados_alunos'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# vamos contar quantos alunos temos

#1º saber onde está o arquivo
#2º pedir que o python leia o arquivo
#3º contar e mostrar as informações

baseDados = "/content/base_dados_alunos/github - Página1.csv"

# base usar uma função de abertura de arquivos
# with open(arquivo, método) és apelido
# métodos - leitura - "r" read (LER)
# métodos - colocar informações - "a" append
# método - deletar tudo e colocar de novo - "w" write

with open(baseDados,"r") as arquivo:
  qtd_linhas = arquivo.readlines()

print(len(qtd_linhas))
# Out:
# 53
